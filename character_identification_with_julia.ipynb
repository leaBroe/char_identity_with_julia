# %% [markdown]
# # Character Identification with the Julia Language

# %% [markdown]
# ## Image Loading
# First, we need to install and load the required packages.

# %%
import Pkg
Pkg.activate("julia_env")
# Out:
# Project julia_env v0.1.0
# Status `~/Downloads/character_identification_with_julia/julia_env/Project.toml` (empty project)
#   Activating project at `~/Downloads/character_identification_with_julia/julia_env`

# %%
Pkg.status()
using Pkg
Pkg.add("Images")
Pkg.add("DataFrames")
using Images
using DataFrames
# Out:
# Project julia_env v0.1.0
# Status `~/Downloads/character_identification_with_julia/julia_env/Project.toml` (empty project)
#    Resolving package versions...
#     Updating `~/Downloads/character_identification_with_julia/julia_env/Project.toml`
#   [916415d5] + Images v0.26.0
#     Updating `~/Downloads/character_identification_with_julia/julia_env/Manifest.toml`
#   [621f4979] + AbstractFFTs v1.5.0
#   [79e6a3ab] + Adapt v4.0.4
# ⌅ [ec485272] + ArnoldiMethod v0.2.0
#   [4fba245c] + ArrayInterface v7.9.0
#   [13072b0f] + AxisAlgorithms v1.1.0
#   [39de3d68] + AxisArrays v0.4.7
#   [62783981] + BitTwiddlingConvenienceFunctions v0.1.5
#   [fa961155] + CEnum v0.5.0
#   [2a0fbf3d] + CPUSummary v0.2.4
#   [aafaddc9] + CatIndices v0.2.2
#   [d360d2e6] + ChainRulesCore v1.23.0
#   [fb6a15b2] + CloseOpenIntervals v0.1.12
#   [aaaa29a8] + Clustering v0.15.7
#   [35d6a980] + ColorSchemes v3.24.0
#   [3da002f7] + ColorTypes v0.11.4
#   [c3611d14] + ColorVectorSpace v0.10.0
# ...

# %%
Pkg.add("CSV")
Pkg.add("FileIO")
# Out:
#    Resolving package versions...
#   No Changes to `~/Downloads/character_identification_with_julia/julia_env/Project.toml`
#   No Changes to `~/Downloads/character_identification_with_julia/julia_env/Manifest.toml`
#    Resolving package versions...
#     Updating `~/Downloads/character_identification_with_julia/julia_env/Project.toml`
#   [5789e2e9] + FileIO v1.16.3
#   No Changes to `~/Downloads/character_identification_with_julia/julia_env/Manifest.toml`

# %% [markdown]
# All the images should be read and stored into a matrix of real numbers. For simplicity, we use the trainResized and testResized data files, as all the images have the same size.
#
# imread() allows us to read the image. float32sc() changes the image into real values. The result could be a single matrix if the image is black/white, or a triple array that contains three matrices representing each color (Red, Green, Blue).
#
# It is easier to work with images with the same representation, so we convert all of the color images to grayscale by averaging the values across the three color matrices.

# %%
using Images, FileIO

function read_data(typeData, labelsInfo, imageSize, path)
    # Initialize x matrix
    x = zeros(Float32, size(labelsInfo, 1), imageSize)
    
    for (index, idImage) in enumerate(labelsInfo["ID"])
        # Construct file name and read image
        nameFile = joinpath(path, "$(typeData)Resized", "$(idImage).Bmp")
        img = load(nameFile)
        
        # Ensure the image is in floating point representation
        temp = float32.(img)
        
        # Convert color images to grayscale if necessary
        if ndims(temp) == 3
            temp = mean(temp, dims=3)
        end
        
        # Flatten the image matrix to a vector and store it in the data matrix
        x[index, :] = reshape(temp, imageSize)
    end
    return x
end
# Out:
# read_data (generic function with 1 method)

# %%
using CSV, DataFrames, Images, FileIO

# Set location of data files, folders
path = "street-view-getting-started-with-julia" # Make sure to replace this with the actual path to your data

# Read information about training data, IDs.
labelsInfoTrain = CSV.read("$(path)/trainLabels.csv", DataFrame)

# Read training matrix
xTrain = read_data("train", labelsInfoTrain, 400, path)

# Read information about test data (IDs).
labelsInfoTest = CSV.read("$(path)/sampleSubmission.csv", DataFrame)

# Read test matrix
xTest = read_data("test", labelsInfoTest, 400, path)
# Out:
# ArgumentError: syntax df[column] is not supported use df[!, column] instead
#
# Stacktrace:
#  [1] getindex(::DataFrame, ::String)
#    @ DataFrames ~/.julia/packages/DataFrames/58MUJ/src/abstractdataframe/abstractdataframe.jl:2480
#  [2] read_data(typeData::String, labelsInfo::DataFrame, imageSize::Int64, path::String)
#    @ Main ./In[20]:7
#  [3] top-level scope
#    @ In[21]:11
